# %%
from datetime import datetime
import time

import numpy as np
import matplotlib.pyplot as plt
import h5py

import uuid
import pprint

import pymongo
from pymongo import MongoClient

# make graphics inline
# %matplotlib inline

# %% [markdown]
# ## Time

# %%
from pytz import timezone
eastern = timezone('US/Eastern')
print('Eastern time: ', eastern.localize(datetime.now()), 'Local time: ', datetime.now())
# Out:
# Eastern time:  2018-06-13 10:49:14.191141-04:00 Local time:  2018-06-13 10:49:14.191252

# %% [markdown]
# ### Database, collection, index information

# %%
client = MongoClient('gpu-001', 27018)
db = client['filestore-new']
col = db['datum']

# %%
col.index_information()
# Out:
# {'_id_': {'key': [('_id', 1)], 'ns': 'filestore-new.datum', 'v': 1},
#  'datum_id_1': {'key': [('datum_id', 1)],
#   'ns': 'filestore-new.datum',
#   'unique': True,
#   'v': 1},
#  'resource_1': {'key': [('resource', 1)], 'ns': 'filestore-new.datum', 'v': 1}}

# %% [markdown]
# ### Bulk insert of 10000 documents with random scattering keys

# %%
resource_id = str(uuid.uuid4())

bulk = col.initialize_unordered_bulk_op()
for i in range(10000):    
    dm = dict(resource=resource_id, datum_id=str(uuid.uuid4()))
    bulk.insert(dm)

# %%
t1 = datetime.now()
bulk.execute()
t2 = datetime.now()
print( "time:", (t2 - t1), " seconds")
# Out:
# time: 0:00:58.255455  seconds

# %% [markdown]
# ### Bulk insert of 10000 documents with random keys prepended with timestamp

# %%
t =  str(datetime.now().timestamp())

# %%
resource_id = str(uuid.uuid4())

bulk = col.initialize_unordered_bulk_op()
for i in range(10000):    
    dm = dict(resource=resource_id, datum_id=t+str(uuid.uuid4()))
    bulk.insert(dm)

# %%
t1 = datetime.now()
bulk.execute()
t2 = datetime.now()
print( "time:", (t2 - t1), " seconds")
# Out:
# time: 0:00:00.262786  seconds

# %% [markdown]
# ### Collection statistics

# %%
pprint.pprint(db.command('collStats', 'datum'))
# Out:
# {'avgObjSize': 165,
#  'capped': False,
#  'count': 191208497,
#  'indexDetails': {'_id_': {'LSM': {'bloom filter false positives': 0,
#                                    'bloom filter hits': 0,
#                                    'bloom filter misses': 0,
#                                    'bloom filter pages evicted from cache': 0,
#                                    'bloom filter pages read into cache': 0,
#                                    'bloom filters in the LSM tree': 0,
#                                    'chunks in the LSM tree': 0,
#                                    'highest merge generation in the LSM tree': 0,
#                                    'queries that could have benefited from a Bloom filter that did not exist': 0,
#                                    'sleep for LSM checkpoint throttle': 0,
#                                    'sleep for LSM merge throttle': 0,
#                                    'total size of bloom filters': 0},
#                            'block-manager': {'allocations requiring file extension': 3,
#                                              'blocks allocated': 9,
#                                              'blocks freed': 3,
#                                              'checkpoint size': 2067521536.0,
#                                              'file allocation unit size': 4096,
#                                              'file bytes available for reuse': 102400,
#                                              'file magic number': 120897,
#                                              'file major version number': 1,
#                                              'file size in bytes': 2067640320.0,
#                                              'minor version number': 0},
#                            'btree': {'btree checkpoint generation': 5,
#                                      'column-store fixed-size leaf pages': 0,
#                                      'column-store internal pages': 0,
#                                      'column-store variable-size RLE encoded values': 0,
#                                      'column-store variable-size deleted values': 0,
#                                      'column-store variable-size leaf pages': 0,
#                                      'fixed-record size': 0,
#                                      'maximum internal page key size': 1474,
#                                      'maximum internal page size': 16384,
#                                      'maximum leaf page key size': 1474,
#                                      'maximum leaf page size': 16384,
#                                      'maximum leaf page value size': 7372,
#                                      'maximum tree depth': 5,
#                                      'number of key/value pairs': 0,
#                                      'overflow pages': 0,
#                                      'pages rewritten by compaction': 0,
#                                      'row-store internal pages': 0,
#                                      'row-store leaf pages': 0},
#                            'cache': {'bytes currently in the cache': 1694645,
#                                      'bytes read into cache': 36468,
#                                      'bytes written from cache': 74507,
#                                      'checkpoint blocked page eviction': 0,
#                                      'data source pages selected for eviction unable to be evicted': 0,
#                                      'hazard pointer blocked page eviction': 0,
#                                      'in-memory page passed criteria to be split': 0,
#                                      'in-memory page splits': 0,
#                                      'internal pages evicted': 0,
#                                      'internal pages split during eviction': 0,
#                                      'leaf pages split during eviction': 0,
#                                      'modified pages evicted': 0,
#                                      'overflow pages read into cache': 0,
#                                      'overflow values cached in memory': 0,
#                                      'page split during eviction deepened the tree': 0,
#                                      'page written requiring lookaside records': 0,
#                                      'pages read into cache': 4,
#                                      'pages read into cache requiring lookaside entries': 0,
#                                      'pages requested from the cache': 60000,
#                                      'pages written from cache': 7,
#                                      'pages written requiring in-memory restoration': 0,
#                                      'tracked dirty bytes in the cache': 1612954,
#                                      'unmodified pages evicted': 0},
#                            'cache_walk': {'Average difference between current eviction generation when the page was last considered': 0,
#                                           'Average on-disk page image size seen': 0,
#                                           'Clean pages currently in cache': 0,
#                                           'Current eviction generation': 0,
#                                           'Dirty pages currently in cache': 0,
#                                           'Entries in the root page': 0,
#                                           'Internal pages currently in cache': 0,
#                                           'Leaf pages currently in cache': 0,
#                                           'Maximum difference between current eviction generation when the page was last considered': 0,
#                                           'Maximum page size seen': 0,
#                                           'Minimum on-disk page image size seen': 0,
#                                           'On-disk page image sizes smaller than a single allocation unit': 0,
#                                           'Pages created in memory and never written': 0,
#                                           'Pages currently queued for eviction': 0,
#                                           'Pages that could not be queued for eviction': 0,
#                                           'Refs skipped during cache traversal': 0,
#                                           'Size of the root page': 0,
#                                           'Total number of pages currently in cache': 0},
#                            'compression': {'compressed pages read': 0,
#                                            'compressed pages written': 0,
#                                            'page written failed to compress': 0,
#                                            'page written was too small to compress': 0,
#                                            'raw compression call failed, additional data available': 0,
#                                            'raw compression call failed, no additional data available': 0,
#                                            'raw compression call succeeded': 0},
#                            'creationString': 'access_pattern_hint=none,allocation_size=4KB,app_metadata=(formatVersion=6,infoObj={ '
#                                              '"v" : 1, "key" : { "_id" : 1 }, '
#                                              '"name" : "_id_", "ns" : '
#                                              '"filestore-new.datum" '
#                                              '}),block_allocation=best,block_compressor=,cache_resident=false,checksum=on,colgroups=,collator=,columns=,dictionary=0,encryption=(keyid=,name=),exclusive=false,extractor=,format=btree,huffman_key=,huffman_value=,ignore_in_memory_cache_size=false,immutable=false,internal_item_max=0,internal_key_max=0,internal_key_truncate=true,internal_page_max=16k,key_format=u,key_gap=10,leaf_item_max=0,leaf_key_max=0,leaf_page_max=16k,leaf_value_max=0,log=(enabled=true),lsm=(auto_throttle=true,bloom=true,bloom_bit_count=16,bloom_config=,bloom_hash_count=8,bloom_oldest=false,chunk_count_limit=0,chunk_max=5GB,chunk_size=10MB,merge_max=15,merge_min=0),memory_page_max=5MB,os_cache_dirty_max=0,os_cache_max=0,prefix_compression=true,prefix_compression_min=4,source=,split_deepen_min_child=0,split_deepen_per_child=0,split_pct=90,type=file,value_format=u',
#                            'cursor': {'bulk-loaded cursor-insert calls': 0,
#                                       'create calls': 1,
#                                       'cursor-insert key and value bytes inserted': 380000,
#                                       'cursor-remove key bytes removed': 0,
#                                       'cursor-update value bytes updated': 0,
#                                       'insert calls': 20000,
#                                       'next calls': 0,
#                                       'prev calls': 0,
#                                       'remove calls': 0,
#                                       'reset calls': 20000,
#                                       'restarted searches': 0,
#                                       'search calls': 0,
#                                       'search near calls': 0,
#                                       'truncate calls': 0,
#                                       'update calls': 0},
#                            'metadata': {'formatVersion': 6,
#                                         'infoObj': '{ "v" : 1, "key" : { "_id" '
#                                                    ': 1 }, "name" : "_id_", '
#                                                    '"ns" : '
#                                                    '"filestore-new.datum" }'},
#                            'reconciliation': {'dictionary matches': 0,
#                                               'fast-path pages deleted': 0,
#                                               'internal page key bytes discarded using suffix compression': 14,
#                                               'internal page multi-block writes': 0,
#                                               'internal-page overflow keys': 0,
#                                               'leaf page key bytes discarded using prefix compression': 63111,
#                                               'leaf page multi-block writes': 1,
#                                               'leaf-page overflow keys': 0,
#                                               'maximum blocks required for a page': 4,
#                                               'overflow values written': 0,
#                                               'page checksum matches': 0,
#                                               'page reconciliation calls': 4,
#                                               'page reconciliation calls for eviction': 0,
#                                               'pages deleted': 0},
#                            'session': {'object compaction': 0,
#                                        'open cursor count': 1},
#                            'transaction': {'update conflicts': 0},
#                            'type': 'file',
#                            'uri': 'statistics:table:index-24--3321994881969307265'},
#                   'datum_id_1': {'LSM': {'bloom filter false positives': 0,
#                                          'bloom filter hits': 0,
#                                          'bloom filter misses': 0,
#                                          'bloom filter pages evicted from cache': 0,
#                                          'bloom filter pages read into cache': 0,
#                                          'bloom filters in the LSM tree': 0,
#                                          'chunks in the LSM tree': 0,
#                                          'highest merge generation in the LSM tree': 0,
#                                          'queries that could have benefited from a Bloom filter that did not exist': 0,
#                                          'sleep for LSM checkpoint throttle': 0,
#                                          'sleep for LSM merge throttle': 0,
#                                          'total size of bloom filters': 0},
#                                  'block-manager': {'allocations requiring file extension': 1,
#                                                    'blocks allocated': 4510,
#                                                    'blocks freed': 4507,
#                                                    'checkpoint size': 8417820672.0,
#                                                    'file allocation unit size': 4096,
#                                                    'file bytes available for reuse': 172568576,
#                                                    'file magic number': 120897,
#                                                    'file major version number': 1,
#                                                    'file size in bytes': 8590589952.0,
#                                                    'minor version number': 0},
#                                  'btree': {'btree checkpoint generation': 5,
#                                            'column-store fixed-size leaf pages': 0,
#                                            'column-store internal pages': 0,
#                                            'column-store variable-size RLE encoded values': 0,
#                                            'column-store variable-size deleted values': 0,
#                                            'column-store variable-size leaf pages': 0,
#                                            'fixed-record size': 0,
#                                            'maximum internal page key size': 1474,
#                                            'maximum internal page size': 16384,
#                                            'maximum leaf page key size': 1474,
#                                            'maximum leaf page size': 16384,
#                                            'maximum leaf page value size': 7372,
#                                            'maximum tree depth': 4,
#                                            'number of key/value pairs': 0,
#                                            'overflow pages': 0,
#                                            'pages rewritten by compaction': 0,
#                                            'row-store internal pages': 0,
#                                            'row-store leaf pages': 0},
#                                  'cache': {'bytes currently in the cache': 294298839,
#                                            'bytes read into cache': 156760807,
#                                            'bytes written from cache': 66589616,
#                                            'checkpoint blocked page eviction': 0,
#                                            'data source pages selected for eviction unable to be evicted': 0,
#                                            'hazard pointer blocked page eviction': 0,
#                                            'in-memory page passed criteria to be split': 0,
#                                            'in-memory page splits': 0,
#                                            'internal pages evicted': 0,
#                                            'internal pages split during eviction': 0,
#                                            'leaf pages split during eviction': 0,
#                                            'modified pages evicted': 0,
#                                            'overflow pages read into cache': 0,
#                                            'overflow values cached in memory': 0,
#                                            'page split during eviction deepened the tree': 0,
#                                            'page written requiring lookaside records': 0,
#                                            'pages read into cache': 10640,
#                                            'pages read into cache requiring lookaside entries': 0,
#                                            'pages requested from the cache': 40000,
#                                            'pages written from cache': 4508,
#                                            'pages written requiring in-memory restoration': 0,
#                                            'tracked dirty bytes in the cache': 156751096,
#                                            'unmodified pages evicted': 0},
#                                  'cache_walk': {'Average difference between current eviction generation when the page was last considered': 0,
#                                                 'Average on-disk page image size seen': 0,
#                                                 'Clean pages currently in cache': 0,
#                                                 'Current eviction generation': 0,
#                                                 'Dirty pages currently in cache': 0,
#                                                 'Entries in the root page': 0,
#                                                 'Internal pages currently in cache': 0,
#                                                 'Leaf pages currently in cache': 0,
#                                                 'Maximum difference between current eviction generation when the page was last considered': 0,
#                                                 'Maximum page size seen': 0,
#                                                 'Minimum on-disk page image size seen': 0,
#                                                 'On-disk page image sizes smaller than a single allocation unit': 0,
#                                                 'Pages created in memory and never written': 0,
#                                                 'Pages currently queued for eviction': 0,
#                                                 'Pages that could not be queued for eviction': 0,
#                                                 'Refs skipped during cache traversal': 0,
#                                                 'Size of the root page': 0,
#                                                 'Total number of pages currently in cache': 0},
#                                  'compression': {'compressed pages read': 0,
#                                                  'compressed pages written': 0,
#                                                  'page written failed to compress': 0,
#                                                  'page written was too small to compress': 0,
#                                                  'raw compression call failed, additional data available': 0,
#                                                  'raw compression call failed, no additional data available': 0,
#                                                  'raw compression call succeeded': 0},
#                                  'creationString': 'access_pattern_hint=none,allocation_size=4KB,app_metadata=(formatVersion=6,infoObj={ '
#                                                    '"v" : 1, "unique" : true, '
#                                                    '"key" : { "datum_id" : 1 '
#                                                    '}, "name" : "datum_id_1", '
#                                                    '"ns" : '
#                                                    '"filestore-new.datum" '
#                                                    '}),block_allocation=best,block_compressor=,cache_resident=false,checksum=on,colgroups=,collator=,columns=,dictionary=0,encryption=(keyid=,name=),exclusive=false,extractor=,format=btree,huffman_key=,huffman_value=,ignore_in_memory_cache_size=false,immutable=false,internal_item_max=0,internal_key_max=0,internal_key_truncate=true,internal_page_max=16k,key_format=u,key_gap=10,leaf_item_max=0,leaf_key_max=0,leaf_page_max=16k,leaf_value_max=0,log=(enabled=true),lsm=(auto_throttle=true,bloom=true,bloom_bit_count=16,bloom_config=,bloom_hash_count=8,bloom_oldest=false,chunk_count_limit=0,chunk_max=5GB,chunk_size=10MB,merge_max=15,merge_min=0),memory_page_max=5MB,os_cache_dirty_max=0,os_cache_max=0,prefix_compression=true,prefix_compression_min=4,source=,split_deepen_min_child=0,split_deepen_per_child=0,split_pct=90,type=file,value_format=u',
#                                  'cursor': {'bulk-loaded cursor-insert calls': 0,
#                                             'create calls': 1,
#                                             'cursor-insert key and value bytes inserted': 1050000,
#                                             'cursor-remove key bytes removed': 0,
#                                             'cursor-update value bytes updated': 0,
#                                             'insert calls': 20000,
#                                             'next calls': 0,
#                                             'prev calls': 0,
#                                             'remove calls': 0,
#                                             'reset calls': 20000,
#                                             'restarted searches': 0,
#                                             'search calls': 0,
#                                             'search near calls': 0,
#                                             'truncate calls': 0,
#                                             'update calls': 0},
#                                  'metadata': {'formatVersion': 6,
#                                               'infoObj': '{ "v" : 1, "unique" '
#                                                          ': true, "key" : { '
#                                                          '"datum_id" : 1 }, '
#                                                          '"name" : '
#                                                          '"datum_id_1", "ns" : '
#                                                          '"filestore-new.datum" '
#                                                          '}'},
#                                  'reconciliation': {'dictionary matches': 0,
#                                                     'fast-path pages deleted': 0,
#                                                     'internal page key bytes discarded using suffix compression': 239474,
#                                                     'internal page multi-block writes': 0,
#                                                     'internal-page overflow keys': 0,
#                                                     'leaf page key bytes discarded using prefix compression': 10164848,
#                                                     'leaf page multi-block writes': 0,
#                                                     'leaf-page overflow keys': 0,
#                                                     'maximum blocks required for a page': 0,
#                                                     'overflow values written': 0,
#                                                     'page checksum matches': 0,
#                                                     'page reconciliation calls': 4508,
#                                                     'page reconciliation calls for eviction': 0,
#                                                     'pages deleted': 0},
#                                  'session': {'object compaction': 0,
#                                              'open cursor count': 1},
#                                  'transaction': {'update conflicts': 0},
#                                  'type': 'file',
#                                  'uri': 'statistics:table:index-33--3321994881969307265'},
#                   'resource_1': {'LSM': {'bloom filter false positives': 0,
#                                          'bloom filter hits': 0,
#                                          'bloom filter misses': 0,
#                                          'bloom filter pages evicted from cache': 0,
#                                          'bloom filter pages read into cache': 0,
#                                          'bloom filters in the LSM tree': 0,
#                                          'chunks in the LSM tree': 0,
#                                          'highest merge generation in the LSM tree': 0,
#                                          'queries that could have benefited from a Bloom filter that did not exist': 0,
#                                          'sleep for LSM checkpoint throttle': 0,
#                                          'sleep for LSM merge throttle': 0,
#                                          'total size of bloom filters': 0},
#                                  'block-manager': {'allocations requiring file extension': 0,
#                                                    'blocks allocated': 6,
#                                                    'blocks freed': 2,
#                                                    'checkpoint size': 865828864,
#                                                    'file allocation unit size': 4096,
#                                                    'file bytes available for reuse': 98304,
#                                                    'file magic number': 120897,
#                                                    'file major version number': 1,
#                                                    'file size in bytes': 865951744,
#                                                    'minor version number': 0},
#                                  'btree': {'btree checkpoint generation': 5,
#                                            'column-store fixed-size leaf pages': 0,
#                                            'column-store internal pages': 0,
#                                            'column-store variable-size RLE encoded values': 0,
#                                            'column-store variable-size deleted values': 0,
#                                            'column-store variable-size leaf pages': 0,
#                                            'fixed-record size': 0,
#                                            'maximum internal page key size': 1474,
#                                            'maximum internal page size': 16384,
#                                            'maximum leaf page key size': 1474,
#                                            'maximum leaf page size': 16384,
#                                            'maximum leaf page value size': 7372,
#                                            'maximum tree depth': 4,
#                                            'number of key/value pairs': 0,
#                                            'overflow pages': 0,
#                                            'pages rewritten by compaction': 0,
#                                            'row-store internal pages': 0,
#                                            'row-store leaf pages': 0},
#                                  'cache': {'bytes currently in the cache': 2472676,
#                                            'bytes read into cache': 70416,
#                                            'bytes written from cache': 52681,
#                                            'checkpoint blocked page eviction': 0,
#                                            'data source pages selected for eviction unable to be evicted': 0,
#                                            'hazard pointer blocked page eviction': 0,
#                                            'in-memory page passed criteria to be split': 0,
#                                            'in-memory page splits': 0,
#                                            'internal pages evicted': 0,
#                                            'internal pages split during eviction': 0,
#                                            'leaf pages split during eviction': 0,
#                                            'modified pages evicted': 0,
#                                            'overflow pages read into cache': 0,
#                                            'overflow values cached in memory': 0,
#                                            'page split during eviction deepened the tree': 0,
#                                            'page written requiring lookaside records': 0,
#                                            'pages read into cache': 5,
#                                            'pages read into cache requiring lookaside entries': 0,
#                                            'pages requested from the cache': 40000,
#                                            'pages written from cache': 4,
#                                            'pages written requiring in-memory restoration': 0,
#                                            'tracked dirty bytes in the cache': 2379338,
#                                            'unmodified pages evicted': 0},
#                                  'cache_walk': {'Average difference between current eviction generation when the page was last considered': 0,
#                                                 'Average on-disk page image size seen': 0,
#                                                 'Clean pages currently in cache': 0,
#                                                 'Current eviction generation': 0,
#                                                 'Dirty pages currently in cache': 0,
#                                                 'Entries in the root page': 0,
#                                                 'Internal pages currently in cache': 0,
#                                                 'Leaf pages currently in cache': 0,
#                                                 'Maximum difference between current eviction generation when the page was last considered': 0,
#                                                 'Maximum page size seen': 0,
#                                                 'Minimum on-disk page image size seen': 0,
#                                                 'On-disk page image sizes smaller than a single allocation unit': 0,
#                                                 'Pages created in memory and never written': 0,
#                                                 'Pages currently queued for eviction': 0,
#                                                 'Pages that could not be queued for eviction': 0,
#                                                 'Refs skipped during cache traversal': 0,
#                                                 'Size of the root page': 0,
#                                                 'Total number of pages currently in cache': 0},
#                                  'compression': {'compressed pages read': 0,
#                                                  'compressed pages written': 0,
#                                                  'page written failed to compress': 0,
#                                                  'page written was too small to compress': 0,
#                                                  'raw compression call failed, additional data available': 0,
#                                                  'raw compression call failed, no additional data available': 0,
#                                                  'raw compression call succeeded': 0},
#                                  'creationString': 'access_pattern_hint=none,allocation_size=4KB,app_metadata=(formatVersion=6,infoObj={ '
#                                                    '"v" : 1, "key" : { '
#                                                    '"resource" : 1 }, "name" : '
#                                                    '"resource_1", "ns" : '
#                                                    '"filestore-new.datum" '
#                                                    '}),block_allocation=best,block_compressor=,cache_resident=false,checksum=on,colgroups=,collator=,columns=,dictionary=0,encryption=(keyid=,name=),exclusive=false,extractor=,format=btree,huffman_key=,huffman_value=,ignore_in_memory_cache_size=false,immutable=false,internal_item_max=0,internal_key_max=0,internal_key_truncate=true,internal_page_max=16k,key_format=u,key_gap=10,leaf_item_max=0,leaf_key_max=0,leaf_page_max=16k,leaf_value_max=0,log=(enabled=true),lsm=(auto_throttle=true,bloom=true,bloom_bit_count=16,bloom_config=,bloom_hash_count=8,bloom_oldest=false,chunk_count_limit=0,chunk_max=5GB,chunk_size=10MB,merge_max=15,merge_min=0),memory_page_max=5MB,os_cache_dirty_max=0,os_cache_max=0,prefix_compression=true,prefix_compression_min=4,source=,split_deepen_min_child=0,split_deepen_per_child=0,split_pct=90,type=file,value_format=u',
#                                  'cursor': {'bulk-loaded cursor-insert calls': 0,
#                                             'create calls': 1,
#                                             'cursor-insert key and value bytes inserted': 880000,
#                                             'cursor-remove key bytes removed': 0,
#                                             'cursor-update value bytes updated': 0,
#                                             'insert calls': 20000,
#                                             'next calls': 0,
#                                             'prev calls': 0,
#                                             'remove calls': 0,
#                                             'reset calls': 20000,
#                                             'restarted searches': 0,
#                                             'search calls': 0,
#                                             'search near calls': 0,
#                                             'truncate calls': 0,
#                                             'update calls': 0},
#                                  'metadata': {'formatVersion': 6,
#                                               'infoObj': '{ "v" : 1, "key" : { '
#                                                          '"resource" : 1 }, '
#                                                          '"name" : '
#                                                          '"resource_1", "ns" : '
#                                                          '"filestore-new.datum" '
#                                                          '}'},
#                                  'reconciliation': {'dictionary matches': 0,
#                                                     'fast-path pages deleted': 0,
#                                                     'internal page key bytes discarded using suffix compression': 3,
#                                                     'internal page multi-block writes': 0,
#                                                     'internal-page overflow keys': 0,
#                                                     'leaf page key bytes discarded using prefix compression': 316229,
#                                                     'leaf page multi-block writes': 1,
#                                                     'leaf-page overflow keys': 0,
#                                                     'maximum blocks required for a page': 2,
#                                                     'overflow values written': 0,
#                                                     'page checksum matches': 0,
#                                                     'page reconciliation calls': 3,
#                                                     'page reconciliation calls for eviction': 0,
#                                                     'pages deleted': 0},
#                                  'session': {'object compaction': 0,
#                                              'open cursor count': 1},
#                                  'transaction': {'update conflicts': 0},
#                                  'type': 'file',
#                                  'uri': 'statistics:table:index-34--3321994881969307265'}},
#  'indexSizes': {'_id_': 2067640320.0,
#                 'datum_id_1': 8590589952.0,
#                 'resource_1': 865951744},
#  'nindexes': 3,
#  'ns': 'filestore-new.datum',
#  'ok': 1.0,
#  'size': 31621043183.0,
#  'storageSize': 14391717888.0,
#  'totalIndexSize': 11524182016.0,
#  'wiredTiger': {'LSM': {'bloom filter false positives': 0,
#                         'bloom filter hits': 0,
#                         'bloom filter misses': 0,
#                         'bloom filter pages evicted from cache': 0,
#                         'bloom filter pages read into cache': 0,
#                         'bloom filters in the LSM tree': 0,
#                         'chunks in the LSM tree': 0,
#                         'highest merge generation in the LSM tree': 0,
#                         'queries that could have benefited from a Bloom filter that did not exist': 0,
#                         'sleep for LSM checkpoint throttle': 0,
#                         'sleep for LSM merge throttle': 0,
#                         'total size of bloom filters': 0},
#                 'block-manager': {'allocations requiring file extension': 17,
#                                   'blocks allocated': 23,
#                                   'blocks freed': 3,
#                                   'checkpoint size': 14391668736.0,
#                                   'file allocation unit size': 4096,
#                                   'file bytes available for reuse': 32768,
#                                   'file magic number': 120897,
#                                   'file major version number': 1,
#                                   'file size in bytes': 14391717888.0,
#                                   'minor version number': 0},
#                 'btree': {'btree checkpoint generation': 5,
#                           'column-store fixed-size leaf pages': 0,
#                           'column-store internal pages': 0,
#                           'column-store variable-size RLE encoded values': 0,
#                           'column-store variable-size deleted values': 0,
#                           'column-store variable-size leaf pages': 0,
#                           'fixed-record size': 0,
#                           'maximum internal page key size': 368,
#                           'maximum internal page size': 4096,
#                           'maximum leaf page key size': 2867,
#                           'maximum leaf page size': 32768,
#                           'maximum leaf page value size': 67108864,
#                           'maximum tree depth': 5,
#                           'number of key/value pairs': 0,
#                           'overflow pages': 0,
#                           'pages rewritten by compaction': 0,
#                           'row-store internal pages': 0,
#                           'row-store leaf pages': 0},
#                 'cache': {'bytes currently in the cache': 4542084,
#                           'bytes read into cache': 25082,
#                           'bytes written from cache': 524495,
#                           'checkpoint blocked page eviction': 0,
#                           'data source pages selected for eviction unable to be evicted': 0,
#                           'hazard pointer blocked page eviction': 0,
#                           'in-memory page passed criteria to be split': 0,
#                           'in-memory page splits': 0,
#                           'internal pages evicted': 0,
#                           'internal pages split during eviction': 0,
#                           'leaf pages split during eviction': 0,
#                           'modified pages evicted': 0,
#                           'overflow pages read into cache': 0,
#                           'overflow values cached in memory': 0,
#                           'page split during eviction deepened the tree': 0,
#                           'page written requiring lookaside records': 0,
#                           'pages read into cache': 4,
#                           'pages read into cache requiring lookaside entries': 0,
#                           'pages requested from the cache': 60003,
#                           'pages written from cache': 21,
#                           'pages written requiring in-memory restoration': 0,
#                           'tracked dirty bytes in the cache': 4507014,
#                           'unmodified pages evicted': 0},
#                 'cache_walk': {'Average difference between current eviction generation when the page was last considered': 0,
#                                'Average on-disk page image size seen': 0,
#                                'Clean pages currently in cache': 0,
#                                'Current eviction generation': 0,
#                                'Dirty pages currently in cache': 0,
#                                'Entries in the root page': 0,
#                                'Internal pages currently in cache': 0,
#                                'Leaf pages currently in cache': 0,
#                                'Maximum difference between current eviction generation when the page was last considered': 0,
#                                'Maximum page size seen': 0,
#                                'Minimum on-disk page image size seen': 0,
#                                'On-disk page image sizes smaller than a single allocation unit': 0,
#                                'Pages created in memory and never written': 0,
#                                'Pages currently queued for eviction': 0,
#                                'Pages that could not be queued for eviction': 0,
#                                'Refs skipped during cache traversal': 0,
#                                'Size of the root page': 0,
#                                'Total number of pages currently in cache': 0},
#                 'compression': {'compressed pages read': 1,
#                                 'compressed pages written': 18,
#                                 'page written failed to compress': 0,
#                                 'page written was too small to compress': 3,
#                                 'raw compression call failed, additional data available': 0,
#                                 'raw compression call failed, no additional data available': 0,
#                                 'raw compression call succeeded': 0},
#                 'creationString': 'access_pattern_hint=none,allocation_size=4KB,app_metadata=(formatVersion=1),block_allocation=best,block_compressor=snappy,cache_resident=false,checksum=on,colgroups=,collator=,columns=,dictionary=0,encryption=(keyid=,name=),exclusive=false,extractor=,format=btree,huffman_key=,huffman_value=,ignore_in_memory_cache_size=false,immutable=false,internal_item_max=0,internal_key_max=0,internal_key_truncate=true,internal_page_max=4KB,key_format=q,key_gap=10,leaf_item_max=0,leaf_key_max=0,leaf_page_max=32KB,leaf_value_max=64MB,log=(enabled=true),lsm=(auto_throttle=true,bloom=true,bloom_bit_count=16,bloom_config=,bloom_hash_count=8,bloom_oldest=false,chunk_count_limit=0,chunk_max=5GB,chunk_size=10MB,merge_max=15,merge_min=0),memory_page_max=10m,os_cache_dirty_max=0,os_cache_max=0,prefix_compression=false,prefix_compression_min=4,source=,split_deepen_min_child=0,split_deepen_per_child=0,split_pct=90,type=file,value_format=u',
#                 'cursor': {'bulk-loaded cursor-insert calls': 0,
#                            'create calls': 1,
#                            'cursor-insert key and value bytes inserted': 2750000,
#                            'cursor-remove key bytes removed': 0,
#                            'cursor-update value bytes updated': 0,
#                            'insert calls': 20000,
#                            'next calls': 0,
#                            'prev calls': 1,
#                            'remove calls': 0,
#                            'reset calls': 20001,
#                            'restarted searches': 0,
#                            'search calls': 0,
#                            'search near calls': 0,
#                            'truncate calls': 0,
#                            'update calls': 0},
#                 'metadata': {'formatVersion': 1},
#                 'reconciliation': {'dictionary matches': 0,
#                                    'fast-path pages deleted': 0,
#                                    'internal page key bytes discarded using suffix compression': 37,
#                                    'internal page multi-block writes': 0,
#                                    'internal-page overflow keys': 0,
#                                    'leaf page key bytes discarded using prefix compression': 0,
#                                    'leaf page multi-block writes': 1,
#                                    'leaf-page overflow keys': 0,
#                                    'maximum blocks required for a page': 18,
#                                    'overflow values written': 0,
#                                    'page checksum matches': 0,
#                                    'page reconciliation calls': 4,
#                                    'page reconciliation calls for eviction': 0,
#                                    'pages deleted': 0},
#                 'session': {'object compaction': 0, 'open cursor count': 1},
#                 'transaction': {'update conflicts': 0},
#                 'type': 'file',
#                 'uri': 'statistics:table:collection-23--3321994881969307265'}}
