# %%
from datetime import datetime
import time

import numpy as np
import matplotlib.pyplot as plt
import h5py

import uuid
import pprint

import pymongo
from pymongo import MongoClient

import warnings
warnings.filterwarnings('ignore')

# make graphics inline
# %matplotlib inline

# %% [markdown]
# ## Select Database and Collection

# %%
client = MongoClient('xf03id1-mdb01', 27017)
fs  = client['filestore-new']
datum = fs['datum']

# %%
datum.count()
# Out:
# 248156649

# %% [markdown]
# Create uuid-based resource ID

# %%
resource_id = str(uuid.uuid4())
print("resource id: ", resource_id)
# Out:
# resource id:  fb8eb5b9-3f7c-410e-9ed7-f10d0edc135b

# %% [markdown]
# ## Bulk insert of 10000 documents with random keys

# %% [markdown]
# Prepape a bulk insert request

# %%
bulk = datum.initialize_unordered_bulk_op()
for i in range(10000):    
    dm = dict(resource=resource_id, datum_id=str(uuid.uuid4()))
    bulk.insert(dm)

# %% [markdown]
# Execute a bulk insert request

# %%
t1 = datetime.now()
results = bulk.execute()
t2 = datetime.now()
print( "time:", (t2 - t1), " seconds")
# Out:
# time: 0:00:24.045399  seconds

# %% [markdown]
# Print results

# %%
print(results)
# Out:
# {'writeErrors': [], 'writeConcernErrors': [], 'nInserted': 10000, 'nUpserted': 0, 'nMatched': 0, 'nModified': 0, 'nRemoved': 0, 'upserted': []}

# %% [markdown]
# ## Bulk insert of 10000 documents with random keys prepended with timestamp

# %% [markdown]
# Create a bulk timestamp

# %%
ts =  str(datetime.now().timestamp())
print("timestamp: ", ts)
# Out:
# timestamp:  1532720130.896131

# %% [markdown]
# Prepape a bulk insert request

# %%
bulk = datum.initialize_unordered_bulk_op()
for i in range(10000):    
    dm = dict(resource=resource_id, datum_id=ts+str(uuid.uuid4()))
    bulk.insert(dm)

# %% [markdown]
# Execute a bulk insert request

# %%
t1 = datetime.now()
results = bulk.execute()
t2 = datetime.now()
print( "time:", (t2 - t1), " seconds")
# Out:
# time: 0:00:00.439803  seconds

# %%
print(results)
# Out:
# {'writeErrors': [], 'writeConcernErrors': [], 'nInserted': 10000, 'nUpserted': 0, 'nMatched': 0, 'nModified': 0, 'nRemoved': 0, 'upserted': []}

# %% [markdown]
# ## Collection statistics

# %%
pprint.pprint(fs.command('collStats', 'datum'))
# Out:
# {'$clusterTime': {'clusterTime': Timestamp(1532720567, 1),
#                   'signature': {'hash': b'\x00\x00\x00\x00\x00\x00\x00\x00'
#                                         b'\x00\x00\x00\x00\x00\x00\x00\x00'
#                                         b'\x00\x00\x00\x00',
#                                 'keyId': 0}},
#  'avgObjSize': 165.0,
#  'capped': False,
#  'count': 248176649,
#  'indexSizes': {'_id_': 2717958144.0,
#                 'datum_id_1': 13433151488.0,
#                 'resource_1': 1067773952},
#  'nchunks': 940,
#  'nindexes': 3,
#  'ns': 'filestore-new.datum',
#  'ok': 1.0,
#  'operationTime': Timestamp(1532720567, 1),
#  'sharded': True,
#  'shards': {'rshxn': {'$clusterTime': {'clusterTime': Timestamp(1532720567, 1),
#                                        'signature': {'hash': b'\x00\x00\x00\x00'
#                                                              b'\x00\x00\x00\x00'
#                                                              b'\x00\x00\x00\x00'
#                                                              b'\x00\x00\x00\x00'
#                                                              b'\x00\x00\x00\x00',
#                                                      'keyId': 0}},
#                       '$configServerState': {'opTime': {'t': 3,
#                                                         'ts': Timestamp(1532720567, 1)}},
#                       '$gleStats': {'electionId': ObjectId('7fffffff0000000000000003'),
#                                     'lastOpTime': Timestamp(0, 0)},
#                       'avgObjSize': 165,
#                       'capped': False,
#                       'count': 248176649,
#                       'indexDetails': {'_id_': {'LSM': {'bloom filter false positives': 0,
#                                                         'bloom filter hits': 0,
#                                                         'bloom filter misses': 0,
#                                                         'bloom filter pages evicted from cache': 0,
#                                                         'bloom filter pages read into cache': 0,
#                                                         'bloom filters in the LSM tree': 0,
#                                                         'chunks in the LSM tree': 0,
#                                                         'highest merge generation in the LSM tree': 0,
#                                                         'queries that could have benefited from a Bloom filter that did not exist': 0,
#                                                         'sleep for LSM checkpoint throttle': 0,
#                                                         'sleep for LSM merge throttle': 0,
#                                                         'total size of bloom filters': 0},
#                                                 'block-manager': {'allocations requiring file extension': 57,
#                                                                   'blocks allocated': 111,
#                                                                   'blocks freed': 29,
#                                                                   'checkpoint size': 2717765632.0,
#                                                                   'file allocation unit size': 4096,
#                                                                   'file bytes available for reuse': 176128,
#                                                                   'file magic number': 120897,
#                                                                   'file major version number': 1,
#                                                                   'file size in bytes': 2717958144.0,
#                                                                   'minor version number': 0},
#                                                 'btree': {'btree checkpoint generation': 13017,
#                                                           'column-store fixed-size leaf pages': 0,
#                                                           'column-store internal pages': 0,
#                                                           'column-store variable-size RLE encoded values': 0,
#                                                           'column-store variable-size deleted values': 0,
#                                                           'column-store variable-size leaf pages': 0,
#                                                           'fixed-record size': 0,
#                                                           'maximum internal page key size': 1474,
#                                                           'maximum internal page size': 16384,
#                                                           'maximum leaf page key size': 1474,
#                                                           'maximum leaf page size': 16384,
#                                                           'maximum leaf page value size': 7372,
#                                                           'maximum tree depth': 5,
#                                                           'number of key/value pairs': 0,
#                                                           'overflow pages': 0,
#                                                           'pages rewritten by compaction': 0,
#                                                           'row-store internal pages': 0,
#                                                           'row-store leaf pages': 0},
#                                                 'cache': {'bytes currently in the cache': 8029359,
#                                                           'bytes read into cache': 75713,
#                                                           'bytes written from cache': 1146536,
#                                                           'checkpoint blocked page eviction': 0,
#                                                           'data source pages selected for eviction unable to be evicted': 0,
#                                                           'eviction walk passes of a file': 3,
#                                                           'eviction walk target pages histogram - 0-9': 0,
#                                                           'eviction walk target pages histogram - 10-31': 3,
#                                                           'eviction walk target pages histogram - 128 and higher': 0,
#                                                           'eviction walk target pages histogram - 32-63': 0,
#                                                           'eviction walk target pages histogram - 64-128': 0,
#                                                           'eviction walks abandoned': 0,
#                                                           'eviction walks gave up because they restarted their walk twice': 3,
#                                                           'eviction walks gave up because they saw too many pages and found no candidates': 0,
#                                                           'eviction walks gave up because they saw too many pages and found too few candidates': 0,
#                                                           'eviction walks reached end of tree': 6,
#                                                           'eviction walks started from root of tree': 3,
#                                                           'eviction walks started from saved location in tree': 0,
#                                                           'hazard pointer blocked page eviction': 0,
#                                                           'in-memory page passed criteria to be split': 2,
#                                                           'in-memory page splits': 1,
#                                                           'internal pages evicted': 2,
#                                                           'internal pages split during eviction': 0,
#                                                           'leaf pages split during eviction': 1,
#                                                           'modified pages evicted': 3,
#                                                           'overflow pages read into cache': 0,
#                                                           'page split during eviction deepened the tree': 0,
#                                                           'page written requiring lookaside records': 0,
#                                                           'pages read into cache': 7,
#                                                           'pages read into cache requiring lookaside entries': 0,
#                                                           'pages requested from the cache': 240003,
#                                                           'pages seen by eviction walk': 9,
#                                                           'pages written from cache': 93,
#                                                           'pages written requiring in-memory restoration': 0,
#                                                           'tracked dirty bytes in the cache': 0,
#                                                           'unmodified pages evicted': 0},
#                                                 'cache_walk': {'Average difference between current eviction generation when the page was last considered': 0,
#                                                                'Average on-disk page image size seen': 0,
#                                                                'Average time in cache for pages that have been visited by the eviction server': 0,
#                                                                'Average time in cache for pages that have not been visited by the eviction server': 0,
#                                                                'Clean pages currently in cache': 0,
#                                                                'Current eviction generation': 0,
#                                                                'Dirty pages currently in cache': 0,
#                                                                'Entries in the root page': 0,
#                                                                'Internal pages currently in cache': 0,
#                                                                'Leaf pages currently in cache': 0,
#                                                                'Maximum difference between current eviction generation when the page was last considered': 0,
#                                                                'Maximum page size seen': 0,
#                                                                'Minimum on-disk page image size seen': 0,
#                                                                'Number of pages never visited by eviction server': 0,
#                                                                'On-disk page image sizes smaller than a single allocation unit': 0,
#                                                                'Pages created in memory and never written': 0,
#                                                                'Pages currently queued for eviction': 0,
#                                                                'Pages that could not be queued for eviction': 0,
#                                                                'Refs skipped during cache traversal': 0,
#                                                                'Size of the root page': 0,
#                                                                'Total number of pages currently in cache': 0},
#                                                 'compression': {'compressed pages read': 0,
#                                                                 'compressed pages written': 0,
#                                                                 'page written failed to compress': 0,
#                                                                 'page written was too small to compress': 0,
#                                                                 'raw compression call failed, additional data available': 0,
#                                                                 'raw compression call failed, no additional data available': 0,
#                                                                 'raw compression call succeeded': 0},
#                                                 'creationString': 'access_pattern_hint=none,allocation_size=4KB,app_metadata=(formatVersion=8,infoObj={ '
#                                                                   '"v" : 2, '
#                                                                   '"key" : { '
#                                                                   '"_id" : 1 '
#                                                                   '}, "name" : '
#                                                                   '"_id_", '
#                                                                   '"ns" : '
#                                                                   '"filestore-new.datum" '
#                                                                   '}),assert=(commit_timestamp=none,read_timestamp=none),block_allocation=best,block_compressor=,cache_resident=false,checksum=on,colgroups=,collator=,columns=,dictionary=0,encryption=(keyid=,name=),exclusive=false,extractor=,format=btree,huffman_key=,huffman_value=,ignore_in_memory_cache_size=false,immutable=false,internal_item_max=0,internal_key_max=0,internal_key_truncate=true,internal_page_max=16k,key_format=u,key_gap=10,leaf_item_max=0,leaf_key_max=0,leaf_page_max=16k,leaf_value_max=0,log=(enabled=true),lsm=(auto_throttle=true,bloom=true,bloom_bit_count=16,bloom_config=,bloom_hash_count=8,bloom_oldest=false,chunk_count_limit=0,chunk_max=5GB,chunk_size=10MB,merge_max=15,merge_min=0),memory_page_max=5MB,os_cache_dirty_max=0,os_cache_max=0,prefix_compression=true,prefix_compression_min=4,source=,split_deepen_min_child=0,split_deepen_per_child=0,split_pct=90,type=file,value_format=u',
#                                                 'cursor': {'bulk-loaded cursor-insert calls': 0,
#                                                            'create calls': 5,
#                                                            'cursor-insert key and value bytes inserted': 1520000,
#                                                            'cursor-remove key bytes removed': 0,
#                                                            'cursor-update value bytes updated': 0,
#                                                            'insert calls': 80000,
#                                                            'modify calls': 0,
#                                                            'next calls': 0,
#                                                            'prev calls': 0,
#                                                            'remove calls': 0,
#                                                            'reserve calls': 0,
#                                                            'reset calls': 80000,
#                                                            'restarted searches': 0,
#                                                            'search calls': 0,
#                                                            'search near calls': 0,
#                                                            'truncate calls': 0,
#                                                            'update calls': 0},
#                                                 'metadata': {'formatVersion': 8,
#                                                              'infoObj': '{ "v" '
#                                                                         ': 2, '
#                                                                         '"key" '
#                                                                         ': { '
#                                                                         '"_id" '
#                                                                         ': 1 '
#                                                                         '}, '
#                                                                         '"name" '
#                                                                         ': '
#                                                                         '"_id_", '
#                                                                         '"ns" '
#                                                                         ': '
#                                                                         '"filestore-new.datum" '
#                                                                         '}'},
#                                                 'reconciliation': {'dictionary matches': 0,
#                                                                    'fast-path pages deleted': 0,
#                                                                    'internal page key bytes discarded using suffix compression': 517,
#                                                                    'internal page multi-block writes': 0,
#                                                                    'internal-page overflow keys': 0,
#                                                                    'leaf page key bytes discarded using prefix compression': 2313514,
#                                                                    'leaf page multi-block writes': 9,
#                                                                    'leaf-page overflow keys': 0,
#                                                                    'maximum blocks required for a page': 1,
#                                                                    'overflow values written': 0,
#                                                                    'page checksum matches': 69,
#                                                                    'page reconciliation calls': 36,
#                                                                    'page reconciliation calls for eviction': 0,
#                                                                    'pages deleted': 0},
#                                                 'session': {'object compaction': 0,
#                                                             'open cursor count': 2},
#                                                 'transaction': {'update conflicts': 0},
#                                                 'type': 'file',
#                                                 'uri': 'statistics:table:index-30-3797219621449874852'},
#                                        'datum_id_1': {'LSM': {'bloom filter false positives': 0,
#                                                               'bloom filter hits': 0,
#                                                               'bloom filter misses': 0,
#                                                               'bloom filter pages evicted from cache': 0,
#                                                               'bloom filter pages read into cache': 0,
#                                                               'bloom filters in the LSM tree': 0,
#                                                               'chunks in the LSM tree': 0,
#                                                               'highest merge generation in the LSM tree': 0,
#                                                               'queries that could have benefited from a Bloom filter that did not exist': 0,
#                                                               'sleep for LSM checkpoint throttle': 0,
#                                                               'sleep for LSM merge throttle': 0,
#                                                               'total size of bloom filters': 0},
#                                                       'block-manager': {'allocations requiring file extension': 8,
#                                                                         'blocks allocated': 48287,
#                                                                         'blocks freed': 48141,
#                                                                         'checkpoint size': 12351926272.0,
#                                                                         'file allocation unit size': 4096,
#                                                                         'file bytes available for reuse': 1079713792.0,
#                                                                         'file magic number': 120897,
#                                                                         'file major version number': 1,
#                                                                         'file size in bytes': 13433151488.0,
#                                                                         'minor version number': 0},
#                                                       'btree': {'btree checkpoint generation': 13017,
#                                                                 'column-store fixed-size leaf pages': 0,
#                                                                 'column-store internal pages': 0,
#                                                                 'column-store variable-size RLE encoded values': 0,
#                                                                 'column-store variable-size deleted values': 0,
#                                                                 'column-store variable-size leaf pages': 0,
#                                                                 'fixed-record size': 0,
#                                                                 'maximum internal page key size': 1474,
#                                                                 'maximum internal page size': 16384,
#                                                                 'maximum leaf page key size': 1474,
#                                                                 'maximum leaf page size': 16384,
#                                                                 'maximum leaf page value size': 7372,
#                                                                 'maximum tree depth': 5,
#                                                                 'number of key/value pairs': 0,
#                                                                 'overflow pages': 0,
#                                                                 'pages rewritten by compaction': 0,
#                                                                 'row-store internal pages': 0,
#                                                                 'row-store leaf pages': 0},
#                                                       'cache': {'bytes currently in the cache': 555967579,
#                                                                 'bytes read into cache': 803616477,
#                                                                 'bytes written from cache': 509460746,
#                                                                 'checkpoint blocked page eviction': 0,
#                                                                 'data source pages selected for eviction unable to be evicted': 42,
#                                                                 'eviction walk passes of a file': 5717,
#                                                                 'eviction walk target pages histogram - 0-9': 588,
#                                                                 'eviction walk target pages histogram - 10-31': 5129,
#                                                                 'eviction walk target pages histogram - 128 and higher': 0,
#                                                                 'eviction walk target pages histogram - 32-63': 0,
#                                                                 'eviction walk target pages histogram - 64-128': 0,
#                                                                 'eviction walks abandoned': 935,
#                                                                 'eviction walks gave up because they restarted their walk twice': 16,
#                                                                 'eviction walks gave up because they saw too many pages and found no candidates': 159,
#                                                                 'eviction walks gave up because they saw too many pages and found too few candidates': 99,
#                                                                 'eviction walks reached end of tree': 685,
#                                                                 'eviction walks started from root of tree': 1209,
#                                                                 'eviction walks started from saved location in tree': 4508,
#                                                                 'hazard pointer blocked page eviction': 1,
#                                                                 'in-memory page passed criteria to be split': 0,
#                                                                 'in-memory page splits': 0,
#                                                                 'internal pages evicted': 1479,
#                                                                 'internal pages split during eviction': 0,
#                                                                 'leaf pages split during eviction': 1,
#                                                                 'modified pages evicted': 11419,
#                                                                 'overflow pages read into cache': 0,
#                                                                 'page split during eviction deepened the tree': 0,
#                                                                 'page written requiring lookaside records': 0,
#                                                                 'pages read into cache': 81656,
#                                                                 'pages read into cache requiring lookaside entries': 0,
#                                                                 'pages requested from the cache': 507799,
#                                                                 'pages seen by eviction walk': 112214,
#                                                                 'pages written from cache': 48271,
#                                                                 'pages written requiring in-memory restoration': 1,
#                                                                 'tracked dirty bytes in the cache': 0,
#                                                                 'unmodified pages evicted': 38865},
#                                                       'cache_walk': {'Average difference between current eviction generation when the page was last considered': 0,
#                                                                      'Average on-disk page image size seen': 0,
#                                                                      'Average time in cache for pages that have been visited by the eviction server': 0,
#                                                                      'Average time in cache for pages that have not been visited by the eviction server': 0,
#                                                                      'Clean pages currently in cache': 0,
#                                                                      'Current eviction generation': 0,
#                                                                      'Dirty pages currently in cache': 0,
#                                                                      'Entries in the root page': 0,
#                                                                      'Internal pages currently in cache': 0,
#                                                                      'Leaf pages currently in cache': 0,
#                                                                      'Maximum difference between current eviction generation when the page was last considered': 0,
#                                                                      'Maximum page size seen': 0,
#                                                                      'Minimum on-disk page image size seen': 0,
#                                                                      'Number of pages never visited by eviction server': 0,
#                                                                      'On-disk page image sizes smaller than a single allocation unit': 0,
#                                                                      'Pages created in memory and never written': 0,
#                                                                      'Pages currently queued for eviction': 0,
#                                                                      'Pages that could not be queued for eviction': 0,
#                                                                      'Refs skipped during cache traversal': 0,
#                                                                      'Size of the root page': 0,
#                                                                      'Total number of pages currently in cache': 0},
#                                                       'compression': {'compressed pages read': 0,
#                                                                       'compressed pages written': 0,
#                                                                       'page written failed to compress': 0,
#                                                                       'page written was too small to compress': 0,
#                                                                       'raw compression call failed, additional data available': 0,
#                                                                       'raw compression call failed, no additional data available': 0,
#                                                                       'raw compression call succeeded': 0},
#                                                       'creationString': 'access_pattern_hint=none,allocation_size=4KB,app_metadata=(formatVersion=8,infoObj={ '
#                                                                         '"v" : '
#                                                                         '2, '
#                                                                         '"unique" '
#                                                                         ': '
#                                                                         'true, '
#                                                                         '"key" '
#                                                                         ': { '
#                                                                         '"datum_id" '
#                                                                         ': 1 '
#                                                                         '}, '
#                                                                         '"name" '
#                                                                         ': '
#                                                                         '"datum_id_1", '
#                                                                         '"ns" '
#                                                                         ': '
#                                                                         '"filestore-new.datum" '
#                                                                         '}),assert=(commit_timestamp=none,read_timestamp=none),block_allocation=best,block_compressor=,cache_resident=false,checksum=on,colgroups=,collator=,columns=,dictionary=0,encryption=(keyid=,name=),exclusive=false,extractor=,format=btree,huffman_key=,huffman_value=,ignore_in_memory_cache_size=false,immutable=false,internal_item_max=0,internal_key_max=0,internal_key_truncate=true,internal_page_max=16k,key_format=u,key_gap=10,leaf_item_max=0,leaf_key_max=0,leaf_page_max=16k,leaf_value_max=0,log=(enabled=true),lsm=(auto_throttle=true,bloom=true,bloom_bit_count=16,bloom_config=,bloom_hash_count=8,bloom_oldest=false,chunk_count_limit=0,chunk_max=5GB,chunk_size=10MB,merge_max=15,merge_min=0),memory_page_max=5MB,os_cache_dirty_max=0,os_cache_max=0,prefix_compression=true,prefix_compression_min=4,source=,split_deepen_min_child=0,split_deepen_per_child=0,split_pct=90,type=file,value_format=u',
#                                                       'cursor': {'bulk-loaded cursor-insert calls': 0,
#                                                                  'create calls': 18,
#                                                                  'cursor-insert key and value bytes inserted': 4200000,
#                                                                  'cursor-remove key bytes removed': 0,
#                                                                  'cursor-update value bytes updated': 0,
#                                                                  'insert calls': 80000,
#                                                                  'modify calls': 0,
#                                                                  'next calls': 160035,
#                                                                  'prev calls': 0,
#                                                                  'remove calls': 0,
#                                                                  'reserve calls': 0,
#                                                                  'reset calls': 90156,
#                                                                  'restarted searches': 0,
#                                                                  'search calls': 0,
#                                                                  'search near calls': 89574,
#                                                                  'truncate calls': 0,
#                                                                  'update calls': 0},
#                                                       'metadata': {'formatVersion': 8,
#                                                                    'infoObj': '{ '
#                                                                               '"v" '
#                                                                               ': '
#                                                                               '2, '
#                                                                               '"unique" '
#                                                                               ': '
#                                                                               'true, '
#                                                                               '"key" '
#                                                                               ': '
#                                                                               '{ '
#                                                                               '"datum_id" '
#                                                                               ': '
#                                                                               '1 '
#                                                                               '}, '
#                                                                               '"name" '
#                                                                               ': '
#                                                                               '"datum_id_1", '
#                                                                               '"ns" '
#                                                                               ': '
#                                                                               '"filestore-new.datum" '
#                                                                               '}'},
#                                                       'reconciliation': {'dictionary matches': 0,
#                                                                          'fast-path pages deleted': 0,
#                                                                          'internal page key bytes discarded using suffix compression': 1285679,
#                                                                          'internal page multi-block writes': 4,
#                                                                          'internal-page overflow keys': 0,
#                                                                          'leaf page key bytes discarded using prefix compression': 73590273,
#                                                                          'leaf page multi-block writes': 6,
#                                                                          'leaf-page overflow keys': 0,
#                                                                          'maximum blocks required for a page': 1,
#                                                                          'overflow values written': 0,
#                                                                          'page checksum matches': 90,
#                                                                          'page reconciliation calls': 48089,
#                                                                          'page reconciliation calls for eviction': 1,
#                                                                          'pages deleted': 0},
#                                                       'session': {'object compaction': 0,
#                                                                   'open cursor count': 2},
#                                                       'transaction': {'update conflicts': 0},
#                                                       'type': 'file',
#                                                       'uri': 'statistics:table:index-39-3797219621449874852'},
#                                        'resource_1': {'LSM': {'bloom filter false positives': 0,
#                                                               'bloom filter hits': 0,
#                                                               'bloom filter misses': 0,
#                                                               'bloom filter pages evicted from cache': 0,
#                                                               'bloom filter pages read into cache': 0,
#                                                               'bloom filters in the LSM tree': 0,
#                                                               'chunks in the LSM tree': 0,
#                                                               'highest merge generation in the LSM tree': 0,
#                                                               'queries that could have benefited from a Bloom filter that did not exist': 0,
#                                                               'sleep for LSM checkpoint throttle': 0,
#                                                               'sleep for LSM merge throttle': 0,
#                                                               'total size of bloom filters': 0},
#                                                       'block-manager': {'allocations requiring file extension': 14,
#                                                                         'blocks allocated': 70,
#                                                                         'blocks freed': 26,
#                                                                         'checkpoint size': 1062744064,
#                                                                         'file allocation unit size': 4096,
#                                                                         'file bytes available for reuse': 4997120,
#                                                                         'file magic number': 120897,
#                                                                         'file major version number': 1,
#                                                                         'file size in bytes': 1067773952,
#                                                                         'minor version number': 0},
#                                                       'btree': {'btree checkpoint generation': 13017,
#                                                                 'column-store fixed-size leaf pages': 0,
#                                                                 'column-store internal pages': 0,
#                                                                 'column-store variable-size RLE encoded values': 0,
#                                                                 'column-store variable-size deleted values': 0,
#                                                                 'column-store variable-size leaf pages': 0,
#                                                                 'fixed-record size': 0,
#                                                                 'maximum internal page key size': 1474,
#                                                                 'maximum internal page size': 16384,
#                                                                 'maximum leaf page key size': 1474,
#                                                                 'maximum leaf page size': 16384,
#                                                                 'maximum leaf page value size': 7372,
#                                                                 'maximum tree depth': 5,
#                                                                 'number of key/value pairs': 0,
#                                                                 'overflow pages': 0,
#                                                                 'pages rewritten by compaction': 0,
#                                                                 'row-store internal pages': 0,
#                                                                 'row-store leaf pages': 0},
#                                                       'cache': {'bytes currently in the cache': 29593033,
#                                                                 'bytes read into cache': 7940582,
#                                                                 'bytes written from cache': 549756,
#                                                                 'checkpoint blocked page eviction': 0,
#                                                                 'data source pages selected for eviction unable to be evicted': 2,
#                                                                 'eviction walk passes of a file': 37,
#                                                                 'eviction walk target pages histogram - 0-9': 1,
#                                                                 'eviction walk target pages histogram - 10-31': 36,
#                                                                 'eviction walk target pages histogram - 128 and higher': 0,
#                                                                 'eviction walk target pages histogram - 32-63': 0,
#                                                                 'eviction walk target pages histogram - 64-128': 0,
#                                                                 'eviction walks abandoned': 9,
#                                                                 'eviction walks gave up because they restarted their walk twice': 16,
#                                                                 'eviction walks gave up because they saw too many pages and found no candidates': 3,
#                                                                 'eviction walks gave up because they saw too many pages and found too few candidates': 0,
#                                                                 'eviction walks reached end of tree': 49,
#                                                                 'eviction walks started from root of tree': 28,
#                                                                 'eviction walks started from saved location in tree': 9,
#                                                                 'hazard pointer blocked page eviction': 0,
#                                                                 'in-memory page passed criteria to be split': 0,
#                                                                 'in-memory page splits': 0,
#                                                                 'internal pages evicted': 80,
#                                                                 'internal pages split during eviction': 0,
#                                                                 'leaf pages split during eviction': 1,
#                                                                 'modified pages evicted': 3,
#                                                                 'overflow pages read into cache': 0,
#                                                                 'page split during eviction deepened the tree': 0,
#                                                                 'page written requiring lookaside records': 0,
#                                                                 'pages read into cache': 642,
#                                                                 'pages read into cache requiring lookaside entries': 0,
#                                                                 'pages requested from the cache': 257013,
#                                                                 'pages seen by eviction walk': 1057,
#                                                                 'pages written from cache': 52,
#                                                                 'pages written requiring in-memory restoration': 0,
#                                                                 'tracked dirty bytes in the cache': 0,
#                                                                 'unmodified pages evicted': 157},
#                                                       'cache_walk': {'Average difference between current eviction generation when the page was last considered': 0,
#                                                                      'Average on-disk page image size seen': 0,
#                                                                      'Average time in cache for pages that have been visited by the eviction server': 0,
#                                                                      'Average time in cache for pages that have not been visited by the eviction server': 0,
#                                                                      'Clean pages currently in cache': 0,
#                                                                      'Current eviction generation': 0,
#                                                                      'Dirty pages currently in cache': 0,
#                                                                      'Entries in the root page': 0,
#                                                                      'Internal pages currently in cache': 0,
#                                                                      'Leaf pages currently in cache': 0,
#                                                                      'Maximum difference between current eviction generation when the page was last considered': 0,
#                                                                      'Maximum page size seen': 0,
#                                                                      'Minimum on-disk page image size seen': 0,
#                                                                      'Number of pages never visited by eviction server': 0,
#                                                                      'On-disk page image sizes smaller than a single allocation unit': 0,
#                                                                      'Pages created in memory and never written': 0,
#                                                                      'Pages currently queued for eviction': 0,
# ...
#                                                                          'internal page multi-block writes': 0,
#                                                                          'internal-page overflow keys': 0,
#                                                                          'leaf page key bytes discarded using prefix compression': 5785515,
#                                                                          'leaf page multi-block writes': 6,
#                                                                          'leaf-page overflow keys': 0,
#                                                                          'maximum blocks required for a page': 1,
#                                                                          'overflow values written': 0,
#                                                                          'page checksum matches': 6,
#                                                                          'page reconciliation calls': 35,
#                                                                          'page reconciliation calls for eviction': 0,
#                                                                          'pages deleted': 0},
#                                                       'session': {'object compaction': 0,
#                                                                   'open cursor count': 2},
#                                                       'transaction': {'update conflicts': 0},
#                                                       'type': 'file',
#                                                       'uri': 'statistics:table:index-40-3797219621449874852'}},
#                       'indexSizes': {'_id_': 2717958144.0,
#                                      'datum_id_1': 13433151488.0,
#                                      'resource_1': 1067773952},
#                       'nindexes': 3,
#                       'ns': 'filestore-new.datum',
#                       'ok': 1.0,
#                       'operationTime': Timestamp(1532720566, 1),
#                       'size': 41049524703.0,
#                       'storageSize': 18691555328.0,
#                       'totalIndexSize': 17218883584.0,
#                       'wiredTiger': {'LSM': {'bloom filter false positives': 0,
#                                              'bloom filter hits': 0,
#                                              'bloom filter misses': 0,
#                                              'bloom filter pages evicted from cache': 0,
#                                              'bloom filter pages read into cache': 0,
#                                              'bloom filters in the LSM tree': 0,
#                                              'chunks in the LSM tree': 0,
#                                              'highest merge generation in the LSM tree': 0,
#                                              'queries that could have benefited from a Bloom filter that did not exist': 0,
#                                              'sleep for LSM checkpoint throttle': 0,
#                                              'sleep for LSM merge throttle': 0,
#                                              'total size of bloom filters': 0},
#                                      'block-manager': {'allocations requiring file extension': 402,
#                                                        'blocks allocated': 456,
#                                                        'blocks freed': 31,
#                                                        'checkpoint size': 18691497984.0,
#                                                        'file allocation unit size': 4096,
#                                                        'file bytes available for reuse': 40960,
#                                                        'file magic number': 120897,
#                                                        'file major version number': 1,
#                                                        'file size in bytes': 18691555328.0,
#                                                        'minor version number': 0},
#                                      'btree': {'btree checkpoint generation': 13017,
#                                                'column-store fixed-size leaf pages': 0,
#                                                'column-store internal pages': 0,
#                                                'column-store variable-size RLE encoded values': 0,
#                                                'column-store variable-size deleted values': 0,
#                                                'column-store variable-size leaf pages': 0,
#                                                'fixed-record size': 0,
#                                                'maximum internal page key size': 368,
#                                                'maximum internal page size': 4096,
#                                                'maximum leaf page key size': 2867,
#                                                'maximum leaf page size': 32768,
#                                                'maximum leaf page value size': 67108864,
#                                                'maximum tree depth': 5,
#                                                'number of key/value pairs': 0,
#                                                'overflow pages': 0,
#                                                'pages rewritten by compaction': 0,
#                                                'row-store internal pages': 0,
#                                                'row-store leaf pages': 0},
#                                      'cache': {'bytes currently in the cache': 163667642,
#                                                'bytes read into cache': 139490654,
#                                                'bytes written from cache': 11621244,
#                                                'checkpoint blocked page eviction': 0,
#                                                'data source pages selected for eviction unable to be evicted': 0,
#                                                'eviction walk passes of a file': 54,
#                                                'eviction walk target pages histogram - 0-9': 2,
#                                                'eviction walk target pages histogram - 10-31': 52,
#                                                'eviction walk target pages histogram - 128 and higher': 0,
#                                                'eviction walk target pages histogram - 32-63': 0,
#                                                'eviction walk target pages histogram - 64-128': 0,
#                                                'eviction walks abandoned': 22,
#                                                'eviction walks gave up because they restarted their walk twice': 12,
#                                                'eviction walks gave up because they saw too many pages and found no candidates': 0,
#                                                'eviction walks gave up because they saw too many pages and found too few candidates': 0,
#                                                'eviction walks reached end of tree': 46,
#                                                'eviction walks started from root of tree': 34,
#                                                'eviction walks started from saved location in tree': 20,
#                                                'hazard pointer blocked page eviction': 0,
#                                                'in-memory page passed criteria to be split': 2,
#                                                'in-memory page splits': 1,
#                                                'internal pages evicted': 9,
#                                                'internal pages split during eviction': 0,
#                                                'leaf pages split during eviction': 1,
#                                                'modified pages evicted': 3,
#                                                'overflow pages read into cache': 0,
#                                                'page split during eviction deepened the tree': 0,
#                                                'page written requiring lookaside records': 0,
#                                                'pages read into cache': 5127,
#                                                'pages read into cache requiring lookaside entries': 0,
#                                                'pages requested from the cache': 508560,
#                                                'pages seen by eviction walk': 576,
#                                                'pages written from cache': 438,
#                                                'pages written requiring in-memory restoration': 0,
#                                                'tracked dirty bytes in the cache': 0,
#                                                'unmodified pages evicted': 335},
#                                      'cache_walk': {'Average difference between current eviction generation when the page was last considered': 0,
#                                                     'Average on-disk page image size seen': 0,
#                                                     'Average time in cache for pages that have been visited by the eviction server': 0,
#                                                     'Average time in cache for pages that have not been visited by the eviction server': 0,
#                                                     'Clean pages currently in cache': 0,
#                                                     'Current eviction generation': 0,
#                                                     'Dirty pages currently in cache': 0,
#                                                     'Entries in the root page': 0,
#                                                     'Internal pages currently in cache': 0,
#                                                     'Leaf pages currently in cache': 0,
#                                                     'Maximum difference between current eviction generation when the page was last considered': 0,
#                                                     'Maximum page size seen': 0,
#                                                     'Minimum on-disk page image size seen': 0,
#                                                     'Number of pages never visited by eviction server': 0,
#                                                     'On-disk page image sizes smaller than a single allocation unit': 0,
#                                                     'Pages created in memory and never written': 0,
#                                                     'Pages currently queued for eviction': 0,
#                                                     'Pages that could not be queued for eviction': 0,
#                                                     'Refs skipped during cache traversal': 0,
#                                                     'Size of the root page': 0,
#                                                     'Total number of pages currently in cache': 0},
#                                      'compression': {'compressed pages read': 4948,
#                                                      'compressed pages written': 407,
#                                                      'page written failed to compress': 0,
#                                                      'page written was too small to compress': 31,
#                                                      'raw compression call failed, additional data available': 0,
#                                                      'raw compression call failed, no additional data available': 0,
#                                                      'raw compression call succeeded': 0},
#                                      'creationString': 'access_pattern_hint=none,allocation_size=4KB,app_metadata=(formatVersion=1),assert=(commit_timestamp=none,read_timestamp=none),block_allocation=best,block_compressor=snappy,cache_resident=false,checksum=on,colgroups=,collator=,columns=,dictionary=0,encryption=(keyid=,name=),exclusive=false,extractor=,format=btree,huffman_key=,huffman_value=,ignore_in_memory_cache_size=false,immutable=false,internal_item_max=0,internal_key_max=0,internal_key_truncate=true,internal_page_max=4KB,key_format=q,key_gap=10,leaf_item_max=0,leaf_key_max=0,leaf_page_max=32KB,leaf_value_max=64MB,log=(enabled=true),lsm=(auto_throttle=true,bloom=true,bloom_bit_count=16,bloom_config=,bloom_hash_count=8,bloom_oldest=false,chunk_count_limit=0,chunk_max=5GB,chunk_size=10MB,merge_max=15,merge_min=0),memory_page_max=10m,os_cache_dirty_max=0,os_cache_max=0,prefix_compression=false,prefix_compression_min=4,source=,split_deepen_min_child=0,split_deepen_per_child=0,split_pct=90,type=file,value_format=u',
#                                      'cursor': {'bulk-loaded cursor-insert calls': 0,
#                                                 'create calls': 19,
#                                                 'cursor-insert key and value bytes inserted': 11000000,
#                                                 'cursor-remove key bytes removed': 0,
#                                                 'cursor-update value bytes updated': 0,
#                                                 'insert calls': 80000,
#                                                 'modify calls': 0,
#                                                 'next calls': 0,
#                                                 'prev calls': 1,
#                                                 'remove calls': 0,
#                                                 'reserve calls': 0,
#                                                 'reset calls': 17060,
#                                                 'restarted searches': 0,
#                                                 'search calls': 774367,
#                                                 'search near calls': 0,
#                                                 'truncate calls': 0,
#                                                 'update calls': 0},
#                                      'metadata': {'formatVersion': 1},
#                                      'reconciliation': {'dictionary matches': 0,
#                                                         'fast-path pages deleted': 0,
#                                                         'internal page key bytes discarded using suffix compression': 1840,
#                                                         'internal page multi-block writes': 6,
#                                                         'internal-page overflow keys': 0,
#                                                         'leaf page key bytes discarded using prefix compression': 0,
#                                                         'leaf page multi-block writes': 9,
#                                                         'leaf-page overflow keys': 0,
#                                                         'maximum blocks required for a page': 1,
#                                                         'overflow values written': 0,
#                                                         'page checksum matches': 520,
#                                                         'page reconciliation calls': 36,
#                                                         'page reconciliation calls for eviction': 0,
#                                                         'pages deleted': 0},
#                                      'session': {'object compaction': 0,
#                                                  'open cursor count': 2},
#                                      'transaction': {'update conflicts': 0},
#                                      'type': 'file',
#                                      'uri': 'statistics:table:collection-29-3797219621449874852'}}},
#  'size': 41049524703.0,
#  'storageSize': 18691555328.0,
#  'totalIndexSize': 17218883584.0}
